# %% [markdown]
# ## HPC環境におけるライフサイエンスAIの開発
# 特定国立研究開発法人 理化学研究所 科技ハブ産連本部　テクニカルスタッフ
# 京都大学大学院医学研究科ビッグデータ医科学分野 共同研究員
# 種石 慶様
# ※HPC；スーパーコンピュータ

# %% [markdown]
# ### AI創薬への期待

# %% [markdown]
# - 簡単なたんぱく質の組み合わせはある程度完成　→　より複雑なたんぱく質の組み合わせ、個々人へ効く薬の作成
# ※　薬　→　タンパク質と化合物の相互作用　この予測のAIを活用（DL以前より）
# - グラフ構造のDL　→　数値化しなくて、下記のような図をインプットとして入れられる
# - シミュレーションとAIの融合
# ※　DLにアウトプットはモデル。シミュレーショのアウトプットはデータ　←文化の違い
# - スーパーコンピュータのインタフェースもjupyterサポートの動きあり。pythonでスーパーコンピュータも動かさせる。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# グラフ構造のDL　githubにアップされている。化学系は一般的な感じ
# - GCM
# - Deepcem

# %% [markdown]
# グラフ構造を畳み込む -Graph Convolutional Networks-　https://qiita.com/tktktks10/items/98d21133cf3e121676c3

# %% [markdown]
# ## 深層学習と転移学習の応用事例
# 立教大学　理学部
# 教授　理学博士　望月　祐志 様

# %% [markdown]
# ### 二次元翼モデルの解析　ポスト処理（見るべき所を見つけれる）

# %% [markdown]
# - 通常の画像認識でOK（時系列データの画像をインプットにして、剥離する場所を見つける）
# - 転移学習とってに有効（新しいアウトプットを追加する事が可能）
# - 今後は、ソルバをモデル化する（始まったばかり）
#
# - 解かせるソルバをメッシュを見せることによって選択するAI　名大　インプットは画像

# %% [markdown]
# ## AIを利用したCFD業務の効率化
# VINAS 　プロジェクト推進部　博士（学術）　小杉 範仁

# %% [markdown]
# - メッシュ生成（人間の知見をAIに学ばせる）　←　ICTとCAEの両方に精通した人が少ない
# -

# %% [markdown]
# ## OCC-Expert/Sculptor V3.8 ：Sculptorの最適化機能OCC, パラメトリック形状モーフィング、形状最適化、Shape Matching、Back2CAD　各機能の最近の開発状況
# VINAS 　プロジェクト推進部　博士（学術）　小杉 範仁

# %% [markdown]
# - shape matching 高速にできる
# - BACK2CAD

# %% [markdown]
# 他の事業所ではopenvspの変わりになるかも

# %% [markdown]
# ## SCULPTORを用いた効率的な四輪車の空力性能開発
# スズキ株式会社　四輪ボディ設計部　第五設計課
# チームリーダー 河野 謙 様

# %% [markdown]
# -

# %% [markdown]
# デルタ（差分）だけなら、メッシュは減らせる！
